# %% [markdown]
# <a href="https://colab.research.google.com/github/Maifariza/Praktikum_Analitik_dan_Visualisasi_Data/blob/main/Checkpoint_2_AVD.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### **Obesity prediction "Obesity Prediction Dataset: Lifestyle & Health Analysis"**

# %% [markdown]
# Sumber Datasets:
#
# [Obesity prediction "Obesity Prediction Dataset: Lifestyle & Health Analysis"](https://www.kaggle.com/datasets/mrsimple07/obesity-prediction?select=obesity_data.csv)
#
#
#
# ---
#
#
# Dataset "Obesity Prediction" ini berisi informasi tentang usia, jenis kelamin, tinggi badan, berat badan, BMI, tingkat aktivitas fisik, dan kategori obesitas untuk memprediksi kategori obesitas seseorang.

# %% [markdown]
# # **DATA UNDERSTANDING**

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from sklearn.cluster import KMeans

df = pd.read_csv("/content/drive/MyDrive/obesity_data (1).csv")

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
print("-----------------------------------")
print("\nMenampilkan Keseluruhan Data:")
print("-----------------------------------")
print(df.to_string())
# Out:
# -----------------------------------
#
# Menampilkan Keseluruhan Data:
# -----------------------------------
#      Age  Height  Weight  BMI  PhysicalActivityLevel ObesityCategory  TDEE
# 0     56     174      72   24                      4   Normal weight    96
# 1     69     164      90   33                      2           Obese    66
# 2     46     168      73   26                      4      Overweight   104
# 3     32     168      85   30                      3      Overweight    90
# 4     60     184      69   20                      3   Normal weight    60
# 5     25     166      61   22                      4   Normal weight    88
# 6     78     184      92   27                      3      Overweight    81
# 7     38     143      59   29                      1      Overweight    29
# 8     56     183      75   22                      4   Normal weight    88
# 9     75     183      82   24                      2   Normal weight    48
# ...

# %%
print("--------------------------------------------------")
print("\nMenampilkan 5 Baris Pertama dan 5 Baris Terakhir:")
print("--------------------------------------------------")
df
# Out:
# --------------------------------------------------
#
# Menampilkan 5 Baris Pertama dan 5 Baris Terakhir:
# --------------------------------------------------
#      Age  Height  Weight  BMI  PhysicalActivityLevel ObesityCategory  TDEE
# 0     56     174      72   24                      4   Normal weight    96
# 1     69     164      90   33                      2           Obese    66
# 2     46     168      73   26                      4      Overweight   104
# 3     32     168      85   30                      3      Overweight    90
# 4     60     184      69   20                      3   Normal weight    60
# ..   ...     ...     ...  ...                    ...             ...   ...
# 995   18     156      64   26                      4      Overweight   104
# 996   35     165      98   36                      1           Obese    36
# 997   49     157      79   32                      1           Obese    32
# ...

# %%
print("-----------------------------------")
print("Menampilkan Beberapa Row Data:")
print("-----------------------------------")
df.head(3)
# Out:
# -----------------------------------
# Menampilkan Beberapa Row Data:
# -----------------------------------
#    Age  Gender      Height     Weight        BMI  PhysicalActivityLevel  \
# 0   56    Male  173.575262  71.982051  23.891783                      4
# 1   69    Male  164.127306  89.959256  33.395209                      2
# 2   46  Female  168.072202  72.930629  25.817737                      4
#
#   ObesityCategory
# 0   Normal weight
# 1           Obese
# 2      Overweight

# %%
print("-----------------------------------")
print("\nMenampilkan 5 baris pertama")
print("-----------------------------------")
print(df.head())
# Out:
# -----------------------------------
#
# Menampilkan 5 baris pertama
# -----------------------------------
#    Age  Gender      Height     Weight        BMI  PhysicalActivityLevel  \
# 0   56    Male  173.575262  71.982051  23.891783                      4
# 1   69    Male  164.127306  89.959256  33.395209                      2
# 2   46  Female  168.072202  72.930629  25.817737                      4
# 3   32    Male  168.459633  84.886912  29.912247                      3
# 4   60    Male  183.568568  69.038945  20.487903                      3
#
#   ObesityCategory
# 0   Normal weight
# 1           Obese
# 2      Overweight
# 3      Overweight
# 4   Normal weight

# %%
print("------------------------------")
print("\nMenampilkan 5 baris terakhir")
print("------------------------------")
df.tail()
# Out:
# ------------------------------
#
# Menampilkan 5 baris terakhir
# ------------------------------
#      Age  Height  Weight  BMI  PhysicalActivityLevel ObesityCategory  TDEE
# 995   18     156      64   26                      4      Overweight   104
# 996   35     165      98   36                      1           Obese    36
# 997   49     157      79   32                      1           Obese    32
# 998   64     164      58   22                      4   Normal weight    88
# 999   66     179      75   23                      1   Normal weight    23

# %%
print("-----------------------------------")
print("\nInformasi Struktur Data:")
print("-----------------------------------")
print(df.info())
# Out:
# -----------------------------------
#
# Informasi Struktur Data:
# -----------------------------------
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 7 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Age                    1000 non-null   int64
#  1   Gender                 1000 non-null   object
#  2   Height                 1000 non-null   float64
#  3   Weight                 1000 non-null   float64
#  4   BMI                    1000 non-null   float64
#  5   PhysicalActivityLevel  1000 non-null   int64
#  6   ObesityCategory        1000 non-null   object
# dtypes: float64(3), int64(2), object(2)
# memory usage: 54.8+ KB
# None

# %%
print("=========================")
print("\nJumlah Baris dan Kolom:")
print("-------------------------")
print(df.shape)
print("=========================")
# Out:
# ...
#
# Jumlah Baris dan Kolom:
# -------------------------
# (1000, 7)
# ...

# %%
print("--------------------------------------------------")
print("\nMenampilkan tipe data setiap kolom dengan df.dtypes:")
print("--------------------------------------------------")

df.dtypes
# Out:
# --------------------------------------------------
#
# Menampilkan tipe data setiap kolom dengan df.dtypes:
# --------------------------------------------------
# Age                        int64
# Gender                    object
# Height                   float64
# Weight                   float64
# BMI                      float64
# PhysicalActivityLevel      int64
# ObesityCategory           object
# dtype: object

# %%
print("--------------------------------------------------")
print("\nMenampilkan statistik deskriptif dengan df.describe():")
print("--------------------------------------------------")
df.describe()
# Out:
# --------------------------------------------------
#
# Menampilkan statistik deskriptif dengan df.describe():
# --------------------------------------------------
#                Age       Height       Weight          BMI  \
# count  1000.000000  1000.000000  1000.000000  1000.000000
# mean     49.857000   170.052417    71.205769    24.888317
# std      18.114267    10.309971    15.509849     6.193912
# min      18.000000   136.115719    26.065730     8.470572
# 25%      35.000000   163.514205    61.129629    20.918068
# 50%      50.000000   169.801665    71.929072    24.698647
# 75%      66.000000   177.353596    81.133746    28.732132
# max      79.000000   201.419670   118.907366    50.791898
#
#        PhysicalActivityLevel
# count            1000.000000
# mean                2.534000
# std                 1.116284
# min                 1.000000
# 25%                 2.000000
# 50%                 3.000000
# 75%                 4.000000
# max                 4.000000

# %%
for col in df.select_dtypes(include=['object']).columns:
    df[col], _ = pd.factorize(df[col])

df_numeric = df.select_dtypes(include=[np.number])

plt.figure(figsize=(10,6))
sns.heatmap(df_numeric.corr(), annot=True, cmap='coolwarm', fmt='.2f')
plt.title("Heatmap Korelasi")
plt.show()

kolom_tertentu = "ObesityCategory"

kategori_obesitas = {0: "Under Weight", 1: "Normal Weight", 2: "Overweight", 3: "Obese"}

print("\nJumlah individu dalam kategori obesitas:")
for key, value in kategori_obesitas.items():
    count = (df['ObesityCategory'] == key).sum()
    print(f"{value}: {count}")

print("----------------------------------------------------")

print("\nMenghitung rata-rata dengan df.mean():")
print(df_numeric.mean())

print("----------------------------------------------------")

print("\nMenghitung median dengan df.median():")
print(df_numeric.median())

print("----------------------------------------------------")

print("\nMenghitung standar deviasi dengan df.std():")
print(df_numeric.std())

print("----------------------------------------------------")

print("\nMenghitung korelasi antar kolom numerik dengan df.corr():")
print(df_numeric.corr())
# Out:
# Jumlah individu dalam kategori obesitas:
# Under Weight: 371
# Normal Weight: 191
# Overweight: 295
# Obese: 143
# ----------------------------------------------------
#
# Menghitung rata-rata dengan df.mean():
# Age                       49.857
# Height                   170.054
# Weight                    71.202
# BMI                       24.877
# PhysicalActivityLevel      2.534
# ObesityCategory            1.210
# TDEE                      63.332
# dtype: float64
# ----------------------------------------------------
#
# Menghitung median dengan df.median():
# Age                       50.0
# Height                   170.0
# Weight                    72.0
# BMI                       25.0
# PhysicalActivityLevel      3.0
# ObesityCategory            1.0
# TDEE                      60.0
# dtype: float64
# ----------------------------------------------------
#
# Menghitung standar deviasi dengan df.std():
# Age                      18.114267
# Height                   10.269398
# ...

# %% [markdown]
# # **DATA PREPARATION**

# %% [markdown]
# ### **Missing Values**

# %% [markdown]
# Tidak ada Missing Values dalam dataset, berarti semua data sudah lengkap dan tidak ada nilai yang hilang.

# %%
print((df.isna().sum() / len(df)) * 100)
# Out:
# Age                      0.0
# Gender                   0.0
# Height                   0.0
# Weight                   0.0
# BMI                      0.0
# PhysicalActivityLevel    0.0
# ObesityCategory          0.0
# dtype: float64

# %% [markdown]
# ### **Duplicated Values**

# %% [markdown]
# Tidak ada Duplicated Values dalam dataset, berarti tidak ada data yang muncul lebih dari satu kali.

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Age, Gender, Height, Weight, BMI, PhysicalActivityLevel, ObesityCategory]
# Index: []

# %%
df = df.drop_duplicates()

# %%
df
# Out:
#      Age  Gender      Height     Weight        BMI  PhysicalActivityLevel  \
# 0     56       0  173.575262  71.982051  23.891783                      4
# 1     69       0  164.127306  89.959256  33.395209                      2
# 2     46       1  168.072202  72.930629  25.817737                      4
# 3     32       0  168.459633  84.886912  29.912247                      3
# 4     60       0  183.568568  69.038945  20.487903                      3
# ..   ...     ...         ...        ...        ...                    ...
# 995   18       0  155.588674  64.103182  26.480345                      4
# 996   35       1  165.076490  97.639771  35.830783                      1
# 997   49       1  156.570956  78.804284  32.146036                      1
# 998   64       0  164.192222  57.978115  21.505965                      4
# 999   66       1  178.537130  74.962164  23.517168                      1
#
#      ObesityCategory
# 0                  0
# 1                  1
# ...

# %% [markdown]
# ### **Outliers**

# %%
results = []

cols = df.select_dtypes(include=['float64', 'int64'])

for col in cols:
  q1 = df[col].quantile(0.25)
  q3 = df[col].quantile(0.75)
  iqr = q3 - q1
  lower_bound = q1 - 1.5*iqr
  upper_bound = q3 + 1.5*iqr
  outliers = df[(df[col] < lower_bound) | (df[col] > upper_bound)]
  percent_outliers = (len(outliers)/len(df))*100
  results.append({'Kolom': col, 'Persentase Outliers': percent_outliers})

# Dataframe dari list hasil
results_df = pd.DataFrame(results)
results_df.set_index('Kolom', inplace=True)
results_df = results_df.rename_axis(None, axis=0).rename_axis('Kolom', axis=1)

# Tampilkan dataframe
display(results_df)
# Out:
# Kolom                  Persentase Outliers
# Age                                    0.0
# Gender                                 0.0
# Height                                 0.6
# Weight                                 1.1
# BMI                                    1.4
# PhysicalActivityLevel                  0.0
# ObesityCategory                        0.0

# %% [markdown]
# Melakukan Imputasi

# %%
columns_to_impute = ["Height", "Weight", "BMI"]

for col in columns_to_impute:
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR

    # Menggunakan .loc[] agar tidak muncul SettingWithCopyWarning
    df.loc[:, col] = df[col].clip(lower=lower_bound, upper=upper_bound)

# %% [markdown]
# Melakukan pengecekan ulang

# %%
results = []

cols = df.select_dtypes(include=['float64', 'int64'])

for col in cols:
  q1 = df[col].quantile(0.25)
  q3 = df[col].quantile(0.75)
  iqr = q3 - q1
  lower_bound = q1 - 1.5*iqr
  upper_bound = q3 + 1.5*iqr
  outliers = df[(df[col] < lower_bound) | (df[col] > upper_bound)]
  percent_outliers = (len(outliers)/len(df))*100
  results.append({'Kolom': col, 'Persentase Outliers': percent_outliers})

# Dataframe dari list hasil
results_df = pd.DataFrame(results)
results_df.set_index('Kolom', inplace=True)
results_df = results_df.rename_axis(None, axis=0).rename_axis('Kolom', axis=1)

# Tampilkan dataframe
display(results_df)
# Out:
# Kolom                  Persentase Outliers
# Age                                    0.0
# Height                                 0.0
# Weight                                 0.0
# BMI                                    0.0
# PhysicalActivityLevel                  0.0

# %%
df
# Out:
#      Age  Gender  Height  Weight  BMI  PhysicalActivityLevel ObesityCategory  \
# 0     56    Male     174      72   24                      4   Normal weight
# 1     69    Male     164      90   33                      2           Obese
# 2     46  Female     168      73   26                      4      Overweight
# 3     32    Male     168      85   30                      3      Overweight
# 4     60    Male     184      69   20                      3   Normal weight
# ..   ...     ...     ...     ...  ...                    ...             ...
# 995   18    Male     156      64   26                      4      Overweight
# 996   35  Female     165      98   36                      1           Obese
# 997   49  Female     157      79   32                      1           Obese
# 998   64    Male     164      58   22                      4   Normal weight
# 999   66  Female     179      75   23                      1   Normal weight
#
#      TDEE
# 0      96
# 1      66
# ...

# %% [markdown]
# ### **Incosistent Value**

# %% [markdown]
# Sebelum diperbaiki:

# %%
df
# Out:
#      Age  Gender      Height     Weight        BMI  PhysicalActivityLevel  \
# 0     56    Male  173.575262  71.982051  23.891783                      4
# 1     69    Male  164.127306  89.959256  33.395209                      2
# 2     46  Female  168.072202  72.930629  25.817737                      4
# 3     32    Male  168.459633  84.886912  29.912247                      3
# 4     60    Male  183.568568  69.038945  20.487903                      3
# ..   ...     ...         ...        ...        ...                    ...
# 995   18    Male  155.588674  64.103182  26.480345                      4
# 996   35  Female  165.076490  97.639771  35.830783                      1
# 997   49  Female  156.570956  78.804284  32.146036                      1
# 998   64    Male  164.192222  57.978115  21.505965                      4
# 999   66  Female  178.537130  74.962164  23.517168                      1
#
#     ObesityCategory
# 0     Normal weight
# 1             Obese
# ...

# %% [markdown]
# Setelah diperbaiki:
#
# Untuk Height, Weight, dan BMI angkanya telah dibulatkan, untuk memudahkan pembaca dalam memahami data.

# %%
df['Height'] = df['Height'].apply(lambda x: round(x * 100) if x < 3 else round(x))
df['Weight'] = df['Weight'].apply(lambda x: round(x / 1000) if x > 300 else round(x))

df['BMI'] = df['Weight'] / ((df['Height'] / 100) ** 2)
df['BMI'] = df['BMI'].apply(round)

print("\nSetelah diperbaiki:")
print(pd.concat([df.head(50), df.tail(50)]))
# Out:
# Setelah diperbaiki:
#      Age  Gender  Height  Weight  BMI  PhysicalActivityLevel ObesityCategory
# 0     56    Male     174      72   24                      4   Normal weight
# 1     69    Male     164      90   33                      2           Obese
# 2     46  Female     168      73   26                      4      Overweight
# 3     32    Male     168      85   30                      3      Overweight
# 4     60    Male     184      69   20                      3   Normal weight
# ..   ...     ...     ...     ...  ...                    ...             ...
# 995   18    Male     156      64   26                      4      Overweight
# 996   35  Female     165      98   36                      1           Obese
# 997   49  Female     157      79   32                      1           Obese
# 998   64    Male     164      58   22                      4   Normal weight
# 999   66  Female     179      75   23                      1   Normal weight
#
# [100 rows x 7 columns]

# %% [markdown]
# ### **Construct Data**

# %% [markdown]
# **Pengertian BMI dan TDEE**
#
#
#
# *  **BMI**, atau Body Mass Index, adalah angka yang dihitung berdasarkan berat badan dan tinggi badan seseorang. BMI digunakan untuk mengelompokkan seseorang ke dalam kategori berat badan tertentu.
#
# *   **TDEE** atau Total Daily Energy Expenditure, adalah jumlah kalori yang tubuhmu butuhkan setiap hari untuk menjalankan fungsi dasar (seperti bernapas dan mencerna makanan) serta aktivitas fisik. TDEE dihitung berdasarkan BMR (Basal Metabolic Rate) dan tingkat aktivitasmu.
#
# Pada bagian Construct Data ini, saya akan menambahkan TDEE dengan rumus
#
# **TDEE** = BMR × Faktor Tingkat Aktivitas

# %%
df["TDEE"] = df["BMI"] * df["PhysicalActivityLevel"]

print(df.head())
# Out:
#    Age  Gender  Height  Weight  BMI  PhysicalActivityLevel ObesityCategory  \
# 0   56    Male     174      72   24                      4   Normal weight
# 1   69    Male     164      90   33                      2           Obese
# 2   46  Female     168      73   26                      4      Overweight
# 3   32    Male     168      85   30                      3      Overweight
# 4   60    Male     184      69   20                      3   Normal weight
#
#    TDEE
# 0    96
# 1    66
# 2   104
# 3    90
# 4    60

# %% [markdown]
# ### **Data Reduction**

# %% [markdown]
# Menghapus kolom Gender karena kurang relevan dengan studi kasus yang saya ambil.

# %%
df = df.drop('Gender', axis=1)

# %%
df
# Out:
#      Age  Height  Weight  BMI  PhysicalActivityLevel ObesityCategory  TDEE
# 0     56     174      72   24                      4   Normal weight    96
# 1     69     164      90   33                      2           Obese    66
# 2     46     168      73   26                      4      Overweight   104
# 3     32     168      85   30                      3      Overweight    90
# 4     60     184      69   20                      3   Normal weight    60
# ..   ...     ...     ...  ...                    ...             ...   ...
# 995   18     156      64   26                      4      Overweight   104
# 996   35     165      98   36                      1           Obese    36
# 997   49     157      79   32                      1           Obese    32
# 998   64     164      58   22                      4   Normal weight    88
# 999   66     179      75   23                      1   Normal weight    23
#
# [1000 rows x 7 columns]
